# %%
import pandas as pd

# %%
df = pd.read_csv('data/media_duration_table.csv')

# %%
df
# Out:
#         Unnamed: 0            media_code  age media_cat  median    Q10  \
# 0                1     1000000012256.ZIP  2.0       PDF    59.0   35.0
# 1                2     1000000012532.ZIP  2.0       PDF    67.0   31.0
# 2                3     1000000012533.ZIP  2.0       PDF   127.0   37.4
# 3                4     1000000012537.ZIP  2.0       PDF    74.0   30.4
# 4                5  BO-20140726013450328  2.0       PDF   893.5  124.4
# 5                6  BO-20140726013450831  2.0       PDF   488.5   83.5
# 6                7  BO-20140726013501917  2.0       PDF   111.5   37.9
# 7                8  BO-20140726013526597  2.0       PDF   363.5   59.6
# 8                9  BO-20140726013527604  2.0       PDF   498.0  113.6
# 9               10  BO-20140726013528612  2.0       PDF   125.5   43.0
# 10              11  BO-20140726013529116  2.0       PDF   374.0   72.9
# 11              12  BO-20140726013530630  2.0       PDF   569.0  111.6
# ...

# %%
rms_df = pd.DataFrame.from_csv('data/bookclub.tb_rms_entity.10k.tsv', sep='\t', header=0)

# %%
rms_df
# Out:
#                rms_packed_seqno           member_code             book_code  \
# rms_seqno
# 78641      RM-20140817222848455  ME-20140817222738373                   NaN
# 78642      RM-20140817222848455  ME-20140817222738373                   NaN
# 78643      RM-20140817225031844  ME-20140817225005784                   NaN
# 78644      RM-20140817225031844  ME-20140817225005784                   NaN
# 78645      RM-20140817225034660  ME-20140817225005784                   NaN
# 78646      RM-20140817225034660  ME-20140817225005784                   NaN
# 78647      RM-20140817225039771  ME-20140817225005784                   NaN
# 78648      RM-20140817225039771  ME-20140817225005784                   NaN
# 78649      RM-20140817225040875  ME-20140817225005784                   NaN
# 78650      RM-20140817225040875  ME-20140817225005784                   NaN
# 78651      RM-20140817225107841  ME-20140817225024623  BO-20140726013720440
# ...

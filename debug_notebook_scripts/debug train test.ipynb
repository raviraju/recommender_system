# %%
import pandas as pd

# %%
test_data = pd.read_csv('recommender_system/books_recommender/train_test_data/test_data.csv', dtype=object)

# %%
test_data.dtypes#[test_data['learner_id'] == 123103.0]
# Out:
# learner_id           object
# book_code            object
# events_count         object
# learner_birthday     object
# learner_gender       object
# dob                  object
# age                  object
# Unnamed: 0_BM        object
# BOOK_META_CODE       object
# BOOK_NAME_BM         object
# AUTHOR               object
# TRANSLATOR           object
# ILLUSTRATOR          object
# PHOTOGRAPHER         object
# SUPERVISOR           object
# BOOK_PLATE           object
# BOOK_EDITION         object
# BINDING_TP           object
# BOOK_INTRO           object
# PUBLISHER_REVIEW     object
# SUMMARY              object
# AUTHOR_INTRO         object
# TOC                  object
# KEYWORD              object
# LYRICS               object
# STORE_CODE           object
# CRE_ID_BM            object
# CRE_IP               object
# CRE_DTIME_BM         object
# UPD_ID_BM            object
#                       ...
# SAP_SALE_PRICE       object
# SAP_CLUBPOINT        object
# ...

# %%
train_data = pd.read_csv('recommender_system/books_recommender/train_test_data/train_data.csv', dtype=object)

# %%
train_data[train_data['book_code'] == 'BO-20140726013720440'][['T_BOOK_NAME', 'T_KEYWORD', 'T_AUTHOR']]
# Out:
#                        T_BOOK_NAME  \
# 66   Really smart primitive people
# 67   Really smart primitive people
# 68   Really smart primitive people
# 69   Really smart primitive people
# 70   Really smart primitive people
# 71   Really smart primitive people
# 72   Really smart primitive people
# 73   Really smart primitive people
# 74   Really smart primitive people
# 75   Really smart primitive people
# 76   Really smart primitive people
# 77   Really smart primitive people
# 78   Really smart primitive people
# 79   Really smart primitive people
# 80   Really smart primitive people
# 81   Really smart primitive people
# 82   Really smart primitive people
# 83   Really smart primitive people
# 84   Really smart primitive people
# 85   Really smart primitive people
# 86   Really smart primitive people
# 87   Really smart primitive people
# 88   Really smart primitive people
# 89   Really smart primitive people
# 90   Really smart primitive people
# ...

# %%
metadata = pd.read_csv('data/BOOKINFORMATION_META.csv')
# Out:
# /home/rraju/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (20,30,38,40,41,44,48,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
metadata.columns
# Out:
# Index(['Unnamed: 0_BM', 'BOOK_META_CODE', 'BOOK_NAME_BM', 'AUTHOR',
#        'TRANSLATOR', 'ILLUSTRATOR', 'PHOTOGRAPHER', 'SUPERVISOR', 'BOOK_PLATE',
#        'BOOK_EDITION', 'BINDING_TP', 'BOOK_INTRO', 'PUBLISHER_REVIEW',
#        'SUMMARY', 'AUTHOR_INTRO', 'TOC', 'KEYWORD', 'LYRICS', 'STORE_CODE',
#        'CRE_ID_BM', 'CRE_IP', 'CRE_DTIME_BM', 'UPD_ID_BM', 'UPD_IP',
#        'UPD_DTIME_BM', 'T_KEYWORD', 'T_BOOK_NAME', 'T_AUTHOR', 'Unnamed: 0_BI',
#        'BOOK_CODE', 'RELATIONGOODS_CODE', 'COMPANY_CODE', 'CONTENTS_CODE',
#        'BOOK_TYPE', 'SERVICE_TYPE', 'BOOK_NAME_BI', 'BOOK_GROUP_CODE',
#        'ONOFF_BOOK_CODE', 'APP_CODE', 'STATUS_TP', 'PAPERBOOK_PUB_DATE',
#        'EBOOK_PUB_DATE', 'EBOOK_PUBLISHER', 'EBOOK_VERSION', 'LANG_CODE',
#        'PAGE_COUNT', 'ISBN10', 'ISBN13', 'FIND_SHOW_YN', 'SAP_CODE',
#        'UP_SAP_CODE', 'SAP_SALE_PRICE', 'SAP_CLUBPOINT', 'SAP_CLUBCASH',
#        'SAP_CLUBMILEAGE', 'INNER_UNIT_COUNT', 'PUBLISHER_CODE', 'PUBLISHER',
# ...

# %%
item = 'BO-20150420190236662'

# %%
metadata[metadata['BOOK_CODE'] == item][['BOOK_NAME_BM', 'T_BOOK_NAME', 'AUTHOR', 'T_AUTHOR']]
# Out:
#       BOOK_NAME_BM                       T_BOOK_NAME AUTHOR  \
# 11011  십자 나사 못의 발명  The invention of a cruciform peg    편집부
#
#                    T_AUTHOR
# 11011  editorial department

# %%
metadata[metadata['BOOK_CODE'] == item][['BOOK_NAME_BM', 'T_BOOK_NAME']]
# Out:
#       BOOK_NAME_BM                               T_BOOK_NAME
# 11011  십자 나사 못의 발명  |persons|nail|character|foot| |I|of|four

# %%
item_id_col = 'book_code'

# %%
train_data[train_data[item_id_col] == 'BO-20161026171156646'][['BOOK_NAME_BM', 'T_BOOK_NAME']]
# Out:
#       BOOK_NAME_BM T_BOOK_NAME
# 12188       아이쿠렐라!   Aikurela!
# 12189       아이쿠렐라!   Aikurela!
# 12190       아이쿠렐라!   Aikurela!
# 12191       아이쿠렐라!   Aikurela!
# 12192       아이쿠렐라!   Aikurela!
# 12193       아이쿠렐라!   Aikurela!
# 12194       아이쿠렐라!   Aikurela!
# 12195       아이쿠렐라!   Aikurela!
# 12196       아이쿠렐라!   Aikurela!
# 12197       아이쿠렐라!   Aikurela!
# 12198       아이쿠렐라!   Aikurela!
# 12199       아이쿠렐라!   Aikurela!
# 12200       아이쿠렐라!   Aikurela!
# 12201       아이쿠렐라!   Aikurela!
# 12202       아이쿠렐라!   Aikurela!
# 12203       아이쿠렐라!   Aikurela!
# 12204       아이쿠렐라!   Aikurela!
# 12205       아이쿠렐라!   Aikurela!
# 12206       아이쿠렐라!   Aikurela!
# 12207       아이쿠렐라!   Aikurela!
# 12208       아이쿠렐라!   Aikurela!
# 12209       아이쿠렐라!   Aikurela!
# 12210       아이쿠렐라!   Aikurela!
# 12211       아이쿠렐라!   Aikurela!
# 12212       아이쿠렐라!   Aikurela!
# 12213       아이쿠렐라!   Aikurela!
# 12214       아이쿠렐라!   Aikurela!
# 12215       아이쿠렐라!   Aikurela!
# 12216       아이쿠렐라!   Aikurela!
# ...
